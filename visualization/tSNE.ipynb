# %% [markdown]
# ### tSNE 的作用：通过视觉直观验证算法的有效性

# %%
import os
import json
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

files = os.listdir('./embeddings/')
print(files)
# Out:
# ['IMDB_sub-embed-899.json', 'IMDB_sub-embed-0.json', 'IMDB_sub-embed-399.json', 'IMDB_sub-embed-699.json', 'IMDB_sub-embed-499.json', 'IMDB_sub-embed-999.json', 'IMDB_sub-embed-799.json', 'IMDB_sub-embed-299.json', 'IMDB_sub-embed-199.json', 'IMDB_sub-embed_best.json', 'IMDB_sub-embed-599.json', 'IMDB_sub-embed-99.json']

# %%
with open('./embeddings/IMDB_sub-embed-0.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb0 = res_dic['ent_embeddings.weight']
    rel_emb0 = res_dic['rel_embeddings.weight']
    ent_emb0 = np.array(ent_emb0).astype(np.float64)
    rel_emb0 = np.array(rel_emb0).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-99.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb1 = res_dic['ent_embeddings.weight']
    rel_emb1 = res_dic['rel_embeddings.weight']
    ent_emb1 = np.array(ent_emb1).astype(np.float64)
    rel_emb1 = np.array(rel_emb1).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-199.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb2 = res_dic['ent_embeddings.weight']
    rel_emb2 = res_dic['rel_embeddings.weight']
    ent_emb2 = np.array(ent_emb2).astype(np.float64)
    rel_emb2 = np.array(rel_emb2).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-299.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb3 = res_dic['ent_embeddings.weight']
    rel_emb3 = res_dic['rel_embeddings.weight']
    ent_emb3 = np.array(ent_emb3).astype(np.float64)
    rel_emb3 = np.array(rel_emb3).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-399.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb4 = res_dic['ent_embeddings.weight']
    rel_emb4 = res_dic['rel_embeddings.weight']
    ent_emb4 = np.array(ent_emb4).astype(np.float64)
    rel_emb4 = np.array(rel_emb4).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-499.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb5 = res_dic['ent_embeddings.weight']
    rel_emb5 = res_dic['rel_embeddings.weight']
    ent_emb5 = np.array(ent_emb5).astype(np.float64)
    rel_emb5 = np.array(rel_emb5).astype(np.float64)

with open('./embeddings/IMDB_sub-embed-599.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb6 = res_dic['ent_embeddings.weight']
    rel_emb6 = res_dic['rel_embeddings.weight']
    ent_emb6 = np.array(ent_emb6).astype(np.float64)
    rel_emb6 = np.array(rel_emb6).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-699.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb7 = res_dic['ent_embeddings.weight']
    rel_emb7 = res_dic['rel_embeddings.weight']
    ent_emb7 = np.array(ent_emb7).astype(np.float64)
    rel_emb7 = np.array(rel_emb7).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-799.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb8 = res_dic['ent_embeddings.weight']
    rel_emb8 = res_dic['rel_embeddings.weight']
    ent_emb8 = np.array(ent_emb8).astype(np.float64)
    rel_emb8 = np.array(rel_emb8).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-899.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb9 = res_dic['ent_embeddings.weight']
    rel_emb9 = res_dic['rel_embeddings.weight']
    ent_emb9 = np.array(ent_emb9).astype(np.float64)
    rel_emb9 = np.array(rel_emb9).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed-999.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb10 = res_dic['ent_embeddings.weight']
    rel_emb10 = res_dic['rel_embeddings.weight']
    ent_emb10 = np.array(ent_emb10).astype(np.float64)
    rel_emb10 = np.array(rel_emb10).astype(np.float64)
    
with open('./embeddings/IMDB_sub-embed_best.json', 'r', encoding='utf-8') as f:
    res_dic = json.load(f)
    ent_emb11 = res_dic['ent_embeddings.weight']
    rel_emb11 = res_dic['rel_embeddings.weight']
    ent_emb11 = np.array(ent_emb11).astype(np.float64)
    rel_emb11 = np.array(rel_emb11).astype(np.float64)

# %%
# 因为样本多，这一步可能要很久（在服务器上跑了约一个小时）
# 如果明天还是运行不完的话，就随机选取一部分实体进行可视化
tsne_rel_embed0 = TSNE(n_components=2, init='random').fit_transform(rel_emb0)    # float32 ndarray
tsne_rel_embed1 = TSNE(n_components=2, init='random').fit_transform(rel_emb1)    # float32 ndarray
tsne_rel_embed2 = TSNE(n_components=2, init='random').fit_transform(rel_emb2)    # float32 ndarray
tsne_rel_embed3 = TSNE(n_components=2, init='random').fit_transform(rel_emb3)    # float32 ndarray
tsne_rel_embed4 = TSNE(n_components=2, init='random').fit_transform(rel_emb4)    # float32 ndarray
tsne_rel_embed5 = TSNE(n_components=2, init='random').fit_transform(rel_emb5)    # float32 ndarray

tsne_rel_embed6 = TSNE(n_components=2, init='random').fit_transform(rel_emb6)
tsne_rel_embed7 = TSNE(n_components=2, init='random').fit_transform(rel_emb7)
tsne_rel_embed8 = TSNE(n_components=2, init='random').fit_transform(rel_emb8)
tsne_rel_embed9 = TSNE(n_components=2, init='random').fit_transform(rel_emb9)
tsne_rel_embed10 = TSNE(n_components=2, init='random').fit_transform(rel_emb10)
tsne_rel_embed11 = TSNE(n_components=2, init='random').fit_transform(rel_emb11)
# Out:
# /home/fwy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/fwy/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:56: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# ...

# %%
tsne_ent_embed0 = TSNE(n_components=2, init='random').fit_transform(ent_emb0)    # float32 ndarray
tsne_ent_embed1 = TSNE(n_components=2, init='random').fit_transform(ent_emb1)    # float32 ndarray
tsne_ent_embed2 = TSNE(n_components=2, init='random').fit_transform(ent_emb2)    # float32 ndarray
tsne_ent_embed3 = TSNE(n_components=2, init='random').fit_transform(ent_emb3)    # float32 ndarray
tsne_ent_embed4 = TSNE(n_components=2, init='random').fit_transform(ent_emb4)    # float32 ndarray
tsne_ent_embed5 = TSNE(n_components=2, init='random').fit_transform(ent_emb5)    # float32 ndarray
# Out:
# /home/fwy/anaconda3/lib/python3.7/site-packages/sklearn/manifold/t_sne.py:344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   error = np.finfo(np.float).max
# /home/fwy/anaconda3/lib/python3.7/site-packages/sklearn/manifold/t_sne.py:345: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   best_error = np.finfo(np.float).max
# ...

# %%
tsne_ent_embed6 = TSNE(n_components=2, init='random').fit_transform(ent_emb6) 
tsne_ent_embed7 = TSNE(n_components=2, init='random').fit_transform(ent_emb7) 
tsne_ent_embed8 = TSNE(n_components=2, init='random').fit_transform(ent_emb8) 
tsne_ent_embed9 = TSNE(n_components=2, init='random').fit_transform(ent_emb9) 
tsne_ent_embed10 = TSNE(n_components=2, init='random').fit_transform(ent_emb10) 
tsne_ent_embed11 = TSNE(n_components=2, init='random').fit_transform(ent_emb11)
# Out:
# /home/fwy/anaconda3/lib/python3.7/site-packages/sklearn/manifold/t_sne.py:344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   error = np.finfo(np.float).max
# /home/fwy/anaconda3/lib/python3.7/site-packages/sklearn/manifold/t_sne.py:345: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   best_error = np.finfo(np.float).max
# ...

# %%
# 12个小图的

plt.style.use('seaborn-white')
fig, ax = plt.subplots(4, 3, figsize=(15, 20))    # 4行，每行3个

ax0 = ax[0][0]
ax1 = ax[0][1]
ax2 = ax[0][2]
ax3 = ax[1][0]
ax4 = ax[1][1]
ax5 = ax[1][2]
ax6 = ax[2][0]
ax7 = ax[2][1]
ax8 = ax[2][2]
ax9 = ax[3][0]
ax10 = ax[3][1]
ax11 = ax[3][2]

ax0.scatter(tsne_rel_embed0[:,0], tsne_rel_embed0[:,1], s=30, c='g')
ax1.scatter(tsne_rel_embed1[:,0], tsne_rel_embed1[:,1], s=30, c='g')
ax2.scatter(tsne_rel_embed2[:,0], tsne_rel_embed2[:,1], s=30, c='g')
ax3.scatter(tsne_rel_embed3[:,0], tsne_rel_embed3[:,1], s=30, c='g')
ax4.scatter(tsne_rel_embed4[:,0], tsne_rel_embed4[:,1], s=30, c='g')
ax5.scatter(tsne_rel_embed5[:,0], tsne_rel_embed5[:,1], s=30, c='g')

ax6.scatter(tsne_rel_embed6[:,0], tsne_rel_embed6[:,1], s=30, c='g')
ax7.scatter(tsne_rel_embed7[:,0], tsne_rel_embed7[:,1], s=30, c='g')
ax8.scatter(tsne_rel_embed8[:,0], tsne_rel_embed8[:,1], s=30, c='g')
ax9.scatter(tsne_rel_embed9[:,0], tsne_rel_embed9[:,1], s=30, c='g')
ax10.scatter(tsne_rel_embed10[:,0], tsne_rel_embed10[:,1], s=30, c='g')
ax11.scatter(tsne_rel_embed11[:,0], tsne_rel_embed11[:,1], s=30, c='g')

ax0.set_title('epoch = 0', fontsize=16)
ax1.set_title('epoch = 99', fontsize=16)
ax2.set_title('epoch = 199', fontsize=16)
ax3.set_title('epoch = 299', fontsize=16)
ax4.set_title('epoch = 399', fontsize=16)
ax5.set_title('epoch = 499', fontsize=16)

ax6.set_title('epoch = 599', fontsize=16)
ax7.set_title('epoch = 699', fontsize=16)
ax8.set_title('epoch = 799', fontsize=16)
ax9.set_title('epoch = 899', fontsize=16)
ax10.set_title('epoch = 999', fontsize=16)
ax11.set_title('epoch = best', fontsize=16)


ax0.set_xlim([-300, 300])
ax0.set_ylim([-300, 300])
ax1.set_xlim([-300, 300])
ax1.set_ylim([-300, 300])
ax2.set_xlim([-300, 300])
ax2.set_ylim([-300, 300])
ax3.set_xlim([-300, 300])
ax3.set_ylim([-300, 300])
ax4.set_xlim([-300, 300])
ax4.set_ylim([-300, 300])
ax5.set_xlim([-300, 300])
ax5.set_ylim([-300, 300])

ax6.set_xlim([-300, 300])
ax6.set_ylim([-300, 300])
ax7.set_xlim([-300, 300])
ax7.set_ylim([-300, 300])
ax8.set_xlim([-300, 300])
ax8.set_ylim([-300, 300])
ax9.set_xlim([-300, 300])
ax9.set_ylim([-300, 300])
ax10.set_xlim([-300, 300])
ax10.set_ylim([-300, 300])
ax11.set_xlim([-300, 300])
ax11.set_ylim([-300, 300])


# 需要限制横纵坐标的取值

fig.tight_layout()
plt.savefig('./rel_emb_12.jpg')
plt.show()

# %%
# 6个小图的

plt.style.use('seaborn-white')
fig, ax = plt.subplots(2, 3, figsize=(15, 10))    # 一张大图包含 2×3 张小图

ax0 = ax[0][0]
ax1 = ax[0][1]
ax2 = ax[0][2]
ax3 = ax[1][0]
ax4 = ax[1][1]
ax5 = ax[1][2]

ax0.scatter(tsne_rel_embed0[:,0], tsne_rel_embed0[:,1], s=30, c='g')
ax1.scatter(tsne_rel_embed1[:,0], tsne_rel_embed1[:,1], s=30, c='g')
ax2.scatter(tsne_rel_embed4[:,0], tsne_rel_embed4[:,1], s=30, c='g')
ax3.scatter(tsne_rel_embed6[:,0], tsne_rel_embed6[:,1], s=30, c='g')
ax4.scatter(tsne_rel_embed9[:,0], tsne_rel_embed9[:,1], s=30, c='g')
ax5.scatter(tsne_rel_embed10[:,0], tsne_rel_embed10[:,1], s=30, c='g')

ax0.set_title('epoch = 0', fontsize=16)
ax1.set_title('epoch = 99', fontsize=16)
ax2.set_title('epoch = 399', fontsize=16)
ax3.set_title('epoch = 599', fontsize=16)
ax4.set_title('epoch = 899', fontsize=16)
ax5.set_title('epoch = 999', fontsize=16)

ax0.set_xlim([-300, 300])
ax0.set_ylim([-300, 300])
ax1.set_xlim([-300, 300])
ax1.set_ylim([-300, 300])
ax2.set_xlim([-300, 300])
ax2.set_ylim([-300, 300])
ax3.set_xlim([-300, 300])
ax3.set_ylim([-300, 300])
ax4.set_xlim([-300, 300])
ax4.set_ylim([-300, 300])
ax5.set_xlim([-300, 300])
ax5.set_ylim([-300, 300])

fig.tight_layout()
plt.savefig('./rel_emb.jpg')
plt.show()

# %%
plt.style.use('seaborn-white')
fig, bx = plt.subplots(4, 3, figsize=(15, 20))    # 4 行，每行 3 张小图

bx0 = bx[0][0]
bx1 = bx[0][1]
bx2 = bx[0][2]
bx3 = bx[1][0]
bx4 = bx[1][1]
bx5 = bx[1][2]
bx6 = bx[2][0]
bx7 = bx[2][1]
bx8 = bx[2][2]
bx9 = bx[3][0]
bx10 = bx[3][1]
bx11 = bx[3][2]

bx0.scatter(tsne_ent_embed0[:,0], tsne_ent_embed0[:,1], s=1)      # c='g'
bx1.scatter(tsne_ent_embed1[:,0], tsne_ent_embed1[:,1], s=1)
bx2.scatter(tsne_ent_embed2[:,0], tsne_ent_embed2[:,1], s=1)
bx3.scatter(tsne_ent_embed3[:,0], tsne_ent_embed3[:,1], s=1)
bx4.scatter(tsne_ent_embed4[:,0], tsne_ent_embed4[:,1], s=1)
bx5.scatter(tsne_ent_embed5[:,0], tsne_ent_embed5[:,1], s=1)

bx6.scatter(tsne_ent_embed6[:,0], tsne_ent_embed6[:,1], s=1)      # c='g'
bx7.scatter(tsne_ent_embed7[:,0], tsne_ent_embed7[:,1], s=1)
bx8.scatter(tsne_ent_embed8[:,0], tsne_ent_embed8[:,1], s=1)
bx9.scatter(tsne_ent_embed9[:,0], tsne_ent_embed9[:,1], s=1)
bx10.scatter(tsne_ent_embed10[:,0], tsne_ent_embed10[:,1], s=1)
bx11.scatter(tsne_ent_embed11[:,0], tsne_ent_embed11[:,1], s=1)


bx0.set_title('epoch = 0', fontsize=16)
bx1.set_title('epoch = 99', fontsize=16)
bx2.set_title('epoch = 199', fontsize=16)
bx3.set_title('epoch = 299', fontsize=16)
bx4.set_title('epoch = 399', fontsize=16)
bx5.set_title('epoch = 499', fontsize=16)

bx6.set_title('epoch = 599', fontsize=16)
bx7.set_title('epoch = 699', fontsize=16)
bx8.set_title('epoch = 799', fontsize=16)
bx9.set_title('epoch = 899', fontsize=16)
bx10.set_title('epoch = 999', fontsize=16)
bx11.set_title('epoch = best', fontsize=16)

fig.tight_layout()
plt.savefig('./ent_emb_12.jpg')
plt.show()

# %%
plt.style.use('seaborn-white')
fig, bx = plt.subplots(2, 3, figsize=(15, 10))    # 一张大图包含 2×3 张小图

bx0 = bx[0][0]
bx1 = bx[0][1]
bx2 = bx[0][2]
bx3 = bx[1][0]
bx4 = bx[1][1]
bx5 = bx[1][2]

bx0.scatter(tsne_ent_embed0[:,0], tsne_ent_embed0[:,1], s=1)      # c='g'
bx1.scatter(tsne_ent_embed1[:,0], tsne_ent_embed1[:,1], s=1)
bx2.scatter(tsne_ent_embed3[:,0], tsne_ent_embed3[:,1], s=1)
bx3.scatter(tsne_ent_embed5[:,0], tsne_ent_embed5[:,1], s=1)
bx4.scatter(tsne_ent_embed7[:,0], tsne_ent_embed7[:,1], s=1)
bx5.scatter(tsne_ent_embed10[:,0], tsne_ent_embed10[:,1], s=1)

bx0.set_title('epoch = 0', fontsize=16)
bx1.set_title('epoch = 99', fontsize=16)
bx2.set_title('epoch = 299', fontsize=16)
bx3.set_title('epoch = 499', fontsize=16)
bx4.set_title('epoch = 699', fontsize=16)
bx5.set_title('epoch = 999', fontsize=16)

fig.tight_layout()
plt.savefig('./ent_emb.jpg')
plt.show()

# %%
# draft

embed0 = np.loadtxt('./embeddings/' + 'relation2vec100_epoch0.init', dtype=np.str, delimiter='\t')
embed0 = embed0[:,:-1].astype(np.float32)
embed1 = np.loadtxt('./embeddings/' + 'relation2vec100_epoch10.init', dtype=np.str, delimiter='\t')
embed1 = embed1[:,:-1].astype(np.float32)
embed2 = np.loadtxt('./embeddings/' + 'relation2vec100_epoch20.init', dtype=np.str, delimiter='\t')
embed2 = embed0[:,:-1].astype(np.float32)
embed3 = np.loadtxt('./embeddings/' + 'relation2vec100_epoch30.init', dtype=np.str, delimiter='\t')
embed3 = embed1[:,:-1].astype(np.float32)
embed4 = np.loadtxt('./embeddings/' + 'relation2vec100_epoch40.init', dtype=np.str, delimiter='\t')
embed4 = embed0[:,:-1].astype(np.float32)
embed5 = np.loadtxt('./embeddings/' + 'relation2vec100_epoch50.init', dtype=np.str, delimiter='\t')
embed5 = embed1[:,:-1].astype(np.float32)
